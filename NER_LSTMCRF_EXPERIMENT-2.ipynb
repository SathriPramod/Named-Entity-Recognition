# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/MyDrive/TEAM-21/lstmcrf"
# Out:
# /content/drive/MyDrive/TEAM-21/lstmcrf

# %%
# !python3 build_data.py
# Out:
# Building vocab...
# - done. 15474 tokens
# {'O', 'B-LOC', 'I-ORG', 'B-ORG', 'I-PERSON', 'B-PERSON', 'I-MISC', 'B-MISC', 'I-LOC'}
# - done. 9 tags
# Building vocab...
# - done. 222582 tokens
# Writing vocab...
# - done. 11192 tokens
# Writing vocab...
# - done. 9 tokens
# Writing vocab...
# - done. 85 tokens

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# !python3 train.py
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/compat/v2_compat.py:68: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
#
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/drive/MyDrive/TEAM-21/lstmcrf/model/ner_model.py:139: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# From /content/drive/MyDrive/TEAM-21/lstmcrf/model/ner_model.py:139: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From /content/drive/MyDrive/TEAM-21/lstmcrf/model/ner_model.py:144: bidirectional_dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.Bidirectional(keras.layers.RNN(cell))`, which is equivalent to this API
# From /content/drive/MyDrive/TEAM-21/lstmcrf/model/ner_model.py:144: bidirectional_dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.Bidirectional(keras.layers.RNN(cell))`, which is equivalent to this API
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/rnn.py:464: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/rnn.py:464: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/rnn_cell_impl.py:958: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/rnn_cell_impl.py:958: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/rnn_cell_impl.py:962: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/rnn_cell_impl.py:962: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/rnn.py:244: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/rnn.py:244: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /content/drive/MyDrive/TEAM-21/lstmcrf/model/ner_model.py:155: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# From /content/drive/MyDrive/TEAM-21/lstmcrf/model/ner_model.py:155: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /content/drive/MyDrive/TEAM-21/lstmcrf/model/ner_model.py:215: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# From /content/drive/MyDrive/TEAM-21/lstmcrf/model/ner_model.py:215: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/TEAM-21/lstmcrf/model/base_model.py:41: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# From /content/drive/MyDrive/TEAM-21/lstmcrf/model/base_model.py:41: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/TEAM-21/lstmcrf/model/base_model.py:43: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# From /content/drive/MyDrive/TEAM-21/lstmcrf/model/base_model.py:43: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# Initializing tf session
# WARNING:tensorflow:From /content/drive/MyDrive/TEAM-21/lstmcrf/model/base_model.py:64: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# From /content/drive/MyDrive/TEAM-21/lstmcrf/model/base_model.py:64: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2022-05-15 07:00:27.095897: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2022-05-15 07:00:27.175344: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-05-15 07:00:27.175439: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (a6c7eea38abc): /proc/driver/nvidia/version does not exist
# 2022-05-15 07:00:27.212013: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2199995000 Hz
# 2022-05-15 07:00:27.212394: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x181b640 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-05-15 07:00:27.212437: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# WARNING:tensorflow:From /content/drive/MyDrive/TEAM-21/lstmcrf/model/base_model.py:65: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# From /content/drive/MyDrive/TEAM-21/lstmcrf/model/base_model.py:65: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/TEAM-21/lstmcrf/model/base_model.py:66: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# From /content/drive/MyDrive/TEAM-21/lstmcrf/model/base_model.py:66: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/TEAM-21/lstmcrf/model/base_model.py:100: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# From /content/drive/MyDrive/TEAM-21/lstmcrf/model/base_model.py:100: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/TEAM-21/lstmcrf/model/base_model.py:101: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# From /content/drive/MyDrive/TEAM-21/lstmcrf/model/base_model.py:101: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# Epoch 1 out of 20
# 131/131 [==============================] - 103s - train loss: 8.1390
# acc 92.78 - f1 66.83
# - new best score!
# Epoch 2 out of 20
# 131/131 [==============================] - 101s - train loss: 3.7332
# acc 95.07 - f1 77.50
# - new best score!
# Epoch 3 out of 20
# 131/131 [==============================] - 102s - train loss: 2.9949
# acc 95.71 - f1 80.87
# - new best score!
# Epoch 4 out of 20
# 131/131 [==============================] - 100s - train loss: 2.5896
# acc 96.30 - f1 83.00
# - new best score!
# Epoch 5 out of 20
# 131/131 [==============================] - 101s - train loss: 2.2653
# acc 96.94 - f1 85.69
# - new best score!
# Epoch 6 out of 20
# 131/131 [==============================] - 102s - train loss: 2.0632
# acc 97.27 - f1 87.59
# - new best score!
# Epoch 7 out of 20
# 131/131 [==============================] - 101s - train loss: 1.8229
# acc 97.68 - f1 89.43
# - new best score!
# Epoch 8 out of 20
# 131/131 [==============================] - 100s - train loss: 1.6926
# acc 98.02 - f1 90.66
# - new best score!
# Epoch 9 out of 20
# 131/131 [==============================] - 100s - train loss: 1.5604
# acc 98.27 - f1 92.06
# - new best score!
# Epoch 10 out of 20
# 131/131 [==============================] - 101s - train loss: 1.3742
# acc 98.50 - f1 92.90
# - new best score!
# Epoch 11 out of 20
# 131/131 [==============================] - 100s - train loss: 1.3462
# acc 98.71 - f1 93.71
# - new best score!
# Epoch 12 out of 20
# 131/131 [==============================] - 100s - train loss: 1.2364
# acc 98.89 - f1 94.71
# - new best score!
# Epoch 13 out of 20
# 131/131 [==============================] - 99s - train loss: 1.1543
# acc 98.96 - f1 95.03
# - new best score!
# Epoch 14 out of 20
# 131/131 [==============================] - 99s - train loss: 1.0624
# acc 99.10 - f1 95.66
# - new best score!
# Epoch 15 out of 20
# 131/131 [==============================] - 98s - train loss: 0.9965
# acc 99.16 - f1 95.94
# - new best score!
# Epoch 16 out of 20
# 131/131 [==============================] - 99s - train loss: 0.9359
# acc 99.22 - f1 96.23
# - new best score!
# Epoch 17 out of 20
# 131/131 [==============================] - 99s - train loss: 0.9170
# acc 99.33 - f1 96.70
# - new best score!
# Epoch 18 out of 20
# 131/131 [==============================] - 99s - train loss: 0.8611
# acc 99.41 - f1 97.04
# - new best score!
# Epoch 19 out of 20
# 131/131 [==============================] - 101s - train loss: 0.8405
# acc 99.47 - f1 97.33
# - new best score!
# Epoch 20 out of 20
# 131/131 [==============================] - 100s - train loss: 0.7616
# acc 99.53 - f1 97.61
# - new best score!

# %%
# !python predict_test.py
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/compat/v2_compat.py:68: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
#
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/drive/MyDrive/TEAM-21/lstmcrf/model/ner_model.py:139: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# From /content/drive/MyDrive/TEAM-21/lstmcrf/model/ner_model.py:139: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From /content/drive/MyDrive/TEAM-21/lstmcrf/model/ner_model.py:144: bidirectional_dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.Bidirectional(keras.layers.RNN(cell))`, which is equivalent to this API
# From /content/drive/MyDrive/TEAM-21/lstmcrf/model/ner_model.py:144: bidirectional_dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.Bidirectional(keras.layers.RNN(cell))`, which is equivalent to this API
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/rnn.py:464: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/rnn.py:464: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/rnn_cell_impl.py:958: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/rnn_cell_impl.py:958: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/rnn_cell_impl.py:962: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/rnn_cell_impl.py:962: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/rnn.py:244: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/rnn.py:244: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /content/drive/MyDrive/TEAM-21/lstmcrf/model/ner_model.py:155: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# From /content/drive/MyDrive/TEAM-21/lstmcrf/model/ner_model.py:155: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /content/drive/MyDrive/TEAM-21/lstmcrf/model/ner_model.py:215: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# From /content/drive/MyDrive/TEAM-21/lstmcrf/model/ner_model.py:215: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/TEAM-21/lstmcrf/model/base_model.py:41: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# From /content/drive/MyDrive/TEAM-21/lstmcrf/model/base_model.py:41: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/TEAM-21/lstmcrf/model/base_model.py:43: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# From /content/drive/MyDrive/TEAM-21/lstmcrf/model/base_model.py:43: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# Initializing tf session
# WARNING:tensorflow:From /content/drive/MyDrive/TEAM-21/lstmcrf/model/base_model.py:64: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# From /content/drive/MyDrive/TEAM-21/lstmcrf/model/base_model.py:64: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2022-05-11 13:18:30.605568: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2022-05-11 13:18:30.618976: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-05-11 13:18:30.619037: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (a4cb7fbf66c8): /proc/driver/nvidia/version does not exist
# 2022-05-11 13:18:30.624841: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200140000 Hz
# 2022-05-11 13:18:30.625085: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x30c6f40 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-05-11 13:18:30.625125: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# WARNING:tensorflow:From /content/drive/MyDrive/TEAM-21/lstmcrf/model/base_model.py:65: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# From /content/drive/MyDrive/TEAM-21/lstmcrf/model/base_model.py:65: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/TEAM-21/lstmcrf/model/base_model.py:66: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# From /content/drive/MyDrive/TEAM-21/lstmcrf/model/base_model.py:66: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# Reloading the latest trained model...
# INFO:tensorflow:Restoring parameters from ../data/LSTM-CRF/checkpoints/9-no-dev/model.weights/
# Restoring parameters from ../data/LSTM-CRF/checkpoints/9-no-dev/model.weights/

# %%
# !perl ../conll_evaluation/conlleval < ../data/LSTM-CRF/predictions/predictions_9-no-dev.txt
# Out:
# processed 9812 tokens with 1293 phrases; found: 1234 phrases; correct: 1092.
# accuracy:  96.49%; precision:  88.49%; recall:  84.45%; FB1:  86.43
#               LOC: precision:  90.25%; recall:  87.33%; FB1:  88.77  359
#              MISC: precision:  95.31%; recall:  94.61%; FB1:  94.96  405
#               ORG: precision:  75.18%; recall:  66.25%; FB1:  70.43  141
#            PERSON: precision:  83.89%; recall:  77.97%; FB1:  80.82  329
